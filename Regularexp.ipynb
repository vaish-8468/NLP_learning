# %% [markdown]
# Website that can be used for generating regular expressions is https://regex101.com/

# %%
import re

# %%
text='''
Jupyter Notebook allows users to compile all aspects of a data project in one place making it easier to show the entire process of a project to your intended audience. Through the web-based application, users can create data visualizations and other components of a project to share with others via the platform. the contact phone number is 8464738377 and (999)-846-3767.
'''
pattern= '\(\d{3}\)-\d{3}-\d{4}|\d{10}'
matches=re.findall(pattern,text)
matches
# Out:
# ['8464738377', '(999)-846-3767']

# %%
text='''
Note-1-jfbjhvfdfdknfkjnjfkj
cygdsguhjfsbkfnkldnjhjf,bjsdjfhjfh hdsbjsdjhdsjdsh sdhbjdujdshjs jsdgjsgjhdsihdsihsfdoid jdshigydsgjc sdjgfjgfhladdsk sdkhfdshfvfsdfs;dkfnfe sdfshdfhsdfhjsd
hdshfvjshfvsdhfv bsdmfbmsdbfvhsd dsfhvshfvjds fbksfbksdjfh sdfbksdhfbhds flbdsjlbflds dslblsdfhb lsdfjhbsdfh dsbfhfbn fshbfshdf hsdfvhdshfb dbnfd

Note-2-jxbjvbjxbvnfv
djsfjbsfjbfs nbdfjbjsdfn dmsfnjdsnfdsf sdnfksdnfkdfm 
'''
pattern= 'Note-\d-[^\n]+'
matches=re.findall(pattern,text)
matches
# Out:
# ['Note-1-jfbjhvfdfdknfkjnjfkj', 'Note-2-jxbjvbjxbvnfv']

# %%
text='''
Note-1-jfbjhvfdfdknfkjnjfkj
cygdsguhjfsbkfnkldnjhjf,bjsdjfhjfh hdsbjsdjhdsjdsh sdhbjdujdshjs jsdgjsgjhdsihdsihsfdoid jdshigydsgjc sdjgfjgfhladdsk sdkhfdshfvfsdfs;dkfnfe sdfshdfhsdfhjsd
hdshfvjshfvsdhfv bsdmfbmsdbfvhsd dsfhvshfvjds fbksfbksdjfh sdfbksdhfbhds flbdsjlbflds dslblsdfhb lsdfjhbsdfh dsbfhfbn fshbfshdf hsdfvhdshfb dbnfd

Note-2-jxbjvbjxbvnfv
djsfjbsfjbfs nbdfjbjsdfn dmsfnjdsnfdsf sdnfksdnfkdfm 
'''
pattern= 'Note-\d-([^\n]*)'
matches=re.findall(pattern,text)
matches
# Out:
# ['jfbjhvfdfdknfkjnjfkj', 'jxbjvbjxbvnfv']
